# %% [markdown]
# <a href="https://colab.research.google.com/github/hujiaying1999/data-crawl-of-jteroffer/blob/main/%E2%80%9CYOLOv5_Tutorial%E2%80%9D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a align="left" href="https://ultralytics.com/yolov5" target="_blank">
# <img width="1024", src="https://user-images.githubusercontent.com/26833433/125273437-35b3fc00-e30d-11eb-9079-46f313325424.png"></a>
#
# This is the **official YOLOv5 🚀 notebook** by **Ultralytics**, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://ultralytics.com. Thank you!

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-66-g26bfd44 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.9/78.2 GB disk)

# %%
# !unzip -q ../data.zip -d ../

# %% [markdown]
# # 1. Inference
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           path/  # directory
#                           path/*.jpg  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights runs/train/exp3/weights/last.pt --img 640 --conf 0.25 --source ../video_test.mp4  --data=data/myposture.yaml
#display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['runs/train/exp3/weights/last.pt'], source=../video_test.mp4, data=data/myposture.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-66-g26bfd44 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/1617) /content/video_test.mp4: 384x640 Done. (0.027s)
# video 1/1 (2/1617) /content/video_test.mp4: 384x640 Done. (0.027s)
# video 1/1 (3/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.026s)
# video 1/1 (4/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (5/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (6/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (7/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (8/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (9/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (10/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (11/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (12/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (13/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (14/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (15/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (16/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (17/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (18/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (19/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (20/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (21/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (22/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (23/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (24/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (25/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (26/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (27/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (28/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (29/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (30/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (31/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (32/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (33/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (34/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (35/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (36/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (37/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (38/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (39/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (40/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (41/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (42/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (43/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (44/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (45/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (46/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (47/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (48/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (49/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (50/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (51/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (52/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (53/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (54/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (55/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (56/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (57/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (58/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (59/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (60/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (61/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (62/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (63/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (64/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (65/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (66/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (67/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (68/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (69/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (70/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (71/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (72/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (73/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (74/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.026s)
# video 1/1 (75/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (76/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (77/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (78/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (79/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (80/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (81/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (82/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (83/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (84/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (85/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (86/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (87/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (88/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (89/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (90/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (91/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (92/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (93/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.026s)
# video 1/1 (94/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (95/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (96/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (97/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (98/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (99/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (100/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (101/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (102/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (103/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (104/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (105/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (106/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (107/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (108/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (109/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (110/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (111/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (112/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (113/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (114/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (115/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (116/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (117/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (118/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (119/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (120/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (121/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (122/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (123/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (124/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (125/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (126/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (127/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (128/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (129/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (130/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (131/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (132/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (133/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (134/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (135/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (136/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (137/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (138/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (139/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (140/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (141/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (142/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (143/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (144/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (145/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (146/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (147/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (148/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (149/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (150/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (151/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (152/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 
1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (517/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.028s)
# video 1/1 (518/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (519/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (520/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (521/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (522/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (523/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (524/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (525/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (526/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (527/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (528/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (529/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (530/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (531/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (532/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (533/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (534/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (535/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (536/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (537/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (538/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (539/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (540/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (541/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (542/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (543/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (544/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (545/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (546/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (547/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (548/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (549/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (550/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (551/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (552/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (553/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (554/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (555/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (556/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (557/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (558/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (559/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (560/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (561/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (562/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (563/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (564/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (565/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# ...
# video 1/1 (1431/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1432/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1433/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1434/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1435/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1436/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1437/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1438/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1439/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1440/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1441/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1442/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1443/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1444/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1445/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1446/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1447/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1448/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1449/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1450/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1451/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1452/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1453/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1454/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1455/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1456/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1457/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1458/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1459/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1460/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1461/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1462/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1463/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1464/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1465/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1466/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1467/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1468/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1469/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1470/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1471/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1472/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1473/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1474/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1475/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1476/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1477/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1478/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1479/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1480/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1481/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1482/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1483/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1484/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1485/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1486/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1487/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1488/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1489/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1490/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1491/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1492/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1493/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1494/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1495/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1496/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1497/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1498/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1499/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1500/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1501/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1502/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1503/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1504/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1505/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1506/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1507/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1508/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1509/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1510/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1511/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1512/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1513/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1514/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1515/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1516/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1517/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1518/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1519/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1520/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1521/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1522/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1523/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1524/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1525/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1526/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1527/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1528/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1529/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1530/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1531/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1532/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1533/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1534/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1535/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1536/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1537/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1538/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1539/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1540/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1541/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1542/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1543/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1544/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1545/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1546/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1547/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1548/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1549/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1550/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1551/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1552/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1553/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1554/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1555/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1556/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1557/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1558/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1559/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1560/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1561/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1562/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1563/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1564/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1565/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1566/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1567/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1568/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1569/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1570/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1571/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1572/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1573/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1574/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1575/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1576/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.028s)
# video 1/1 (1577/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1578/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1579/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1580/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1581/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1582/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1583/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1584/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1585/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1586/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1587/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1588/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1589/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1590/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1591/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1592/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1593/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1594/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1595/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1596/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1597/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1598/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1599/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1600/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1601/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1602/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1603/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1604/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1605/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1606/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1607/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1608/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1609/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1610/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1611/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1612/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1613/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1614/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1615/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# video 1/1 (1616/1617) /content/video_test.mp4: 384x640 1 distraction, Done. (0.027s)
# Speed: 0.5ms pre-process, 26.8ms inference, 1.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
# !python detect.py --weights runs/train/exp3/weights/last.pt --img 640 --conf 0.25 --source 0 --data data/myposture.yaml
# Out:
# detect: weights=['runs/train/exp3/weights/last.pt'], source=0, data=data/myposture.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-66-g26bfd44 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# WARNING: Environment does not support cv2.imshow() or PIL Image.show() image displays
# cv2.imshow() is disabled in Google Colab environments
# [ WARN:0] global /io/opencv/modules/videoio/src/cap_v4l.cpp (802) open VIDEOIO ERROR: V4L: can't open camera by index 0
# Traceback (most recent call last):
#   File "detect.py", line 251, in <module>
#     main(opt)
#   File "detect.py", line 246, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 28, in decorate_context
#     return func(*args, **kwargs)
#   File "detect.py", line 99, in run
#     dataset = LoadStreams(source, img_size=imgsz, stride=stride, auto=pt)
#   File "/content/yolov5/utils/datasets.py", line 310, in __init__
#     assert cap.isOpened(), f'{st}Failed to open {s}'
# AssertionError: 1/1: 0... Failed to open 0

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/127574988-6a558aa1-d268-44b9-bf6b-62d4c605cc72.jpg" width="600">

# %% [markdown]
# # 2. Validate
# Validate a model's accuracy on [COCO](https://cocodataset.org/#home) val or test-dev datasets. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag. Note that `pycocotools` metrics may be ~1% better than the equivalent repo metrics, as is visible below, due to slight differences in mAP computation.

# %% [markdown]
# ## COCO val
# Download [COCO val 2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L14) dataset (1GB - 5000 images), and test model accuracy.

# %%
# Download COCO val
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip
# Out:
#   0%|          | 0.00/780M [00:00<?, ?B/s]

# %%
# Run YOLOv5x on COCO val
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half
# Out:
# val: data=/content/yolov5/data/coco.yaml, weights=['yolov5x.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=True
# YOLOv5 🚀 v6.0-48-g84a8099 torch 1.10.0+cu102 CUDA:0 (Tesla V100-SXM2-16GB, 16160MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.0/yolov5x.pt to yolov5x.pt...
# 100% 166M/166M [00:03<00:00, 54.1MB/s]
#
# Fusing layers...
# Model Summary: 444 layers, 86705005 parameters, 0 gradients
# val: Scanning '../datasets/coco/val2017' images and labels...4952 found, 48 missing, 0 empty, 0 corrupted: 100% 5000/5000 [00:01<00:00, 2636.64it/s]
# val: New cache created: ../datasets/coco/val2017.cache
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 157/157 [01:12<00:00,  2.17it/s]
#                  all       5000      36335      0.729       0.63      0.683      0.496
# Speed: 0.1ms pre-process, 4.9ms inference, 1.9ms NMS per image at shape (32, 3, 640, 640)
#
# Evaluating pycocotools mAP... saving runs/val/exp/yolov5x_predictions.json...
# loading annotations into memory...
# Done (t=0.46s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=5.15s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=90.39s).
# Accumulating evaluation results...
# DONE (t=14.54s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.507
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.689
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.552
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.345
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.559
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.652
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.381
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.630
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.682
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.732
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.829
# Results saved to runs/val/exp

# %% [markdown]
# ## COCO test
# Download [COCO test2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L15) dataset (7GB - 40,000 images), to test model accuracy on test-dev set (**20,000 images, no labels**). Results are saved to a `*.json` file which should be **zipped** and submitted to the evaluation server at https://competitions.codalab.org/competitions/20794.

# %%
# Download COCO test-dev2017
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017labels.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip
# !f="test2017.zip" && curl http://images.cocodataset.org/zips/$f -o $f && unzip -q $f -d ../datasets/coco/images

# %%
# Run YOLOv5x on COCO test
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half --task test

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="1000" src="https://uploads-ssl.webflow.com/5f6bc60e665f54545a1e52a5/615627e5824c9c6195abfda9_computer-vision-cycle.png"/></a></p>
# Close the active learning loop by sampling images from your inference conditions with the `roboflow` pip package
# <br><br>
#
# Train a YOLOv5s model on the [COCO128](https://www.kaggle.com/ultralytics/coco128) dataset with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`.
#
# - **Pretrained [Models](https://github.com/ultralytics/yolov5/tree/master/models)** are downloaded
# automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases)
# - **[Datasets](https://github.com/ultralytics/yolov5/tree/master/data)** available for autodownload include: [COCO](https://github.com/ultralytics/yolov5/blob/master/data/coco.yaml), [COCO128](https://github.com/ultralytics/yolov5/blob/master/data/coco128.yaml), [VOC](https://github.com/ultralytics/yolov5/blob/master/data/VOC.yaml), [Argoverse](https://github.com/ultralytics/yolov5/blob/master/data/Argoverse.yaml), [VisDrone](https://github.com/ultralytics/yolov5/blob/master/data/VisDrone.yaml), [GlobalWheat](https://github.com/ultralytics/yolov5/blob/master/data/GlobalWheat2020.yaml), [xView](https://github.com/ultralytics/yolov5/blob/master/data/xView.yaml), [Objects365](https://github.com/ultralytics/yolov5/blob/master/data/Objects365.yaml), [SKU-110K](https://github.com/ultralytics/yolov5/blob/master/data/SKU-110K.yaml).
# - **Training Results** are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.
# <br><br>
#
# ## Train on Custom Data with Roboflow 🌟 NEW
#
# [Roboflow](https://roboflow.com/?ref=ultralytics) enables you to easily **organize, label, and prepare** a high quality dataset with your own custom data. Roboflow also makes it easy to establish an active learning pipeline, collaborate with your team on dataset improvement, and integrate directly into your model building workflow with the `roboflow` pip package.
#
# - Custom Training Example: [https://blog.roboflow.com/how-to-train-yolov5-on-a-custom-dataset/](https://blog.roboflow.com/how-to-train-yolov5-on-a-custom-dataset/?ref=ultralytics)
# - Custom Training Notebook: [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/yolov5-custom-training-tutorial/blob/main/yolov5-custom-training.ipynb)
# <br>
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="480" src="https://uploads-ssl.webflow.com/5f6bc60e665f54545a1e52a5/6152a275ad4b4ac20cd2e21a_roboflow-annotate.gif"/></a></p>Label images lightning fast (including with model-assisted labeling)

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 5 --epochs 70 --data myposture.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=myposture.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=70, batch_size=5, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 4), reused 5 (delta 4), pack-reused 0
# Unpacking objects: 100% (6/6), done.
# From https://github.com/ultralytics/yolov5
#    26bfd44..e19f87e  master              -> origin/master
#    7c0ba0d..1f77825  test/conv_reduction -> origin/test/conv_reduction
# github: ⚠️ YOLOv5 is out of date by 1 commit. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-66-g26bfd44 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=4
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     24273  models.yolo.Detect                      [4, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 270 layers, 7030417 parameters, 7030417 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# Scaled weight_decay = 0.0005078125
# optimizer: SGD with parameter groups 57 weight (no decay), 60 weight, 60 bias
# albumentations: version 1.0.3 required by YOLOv5, but version 0.1.12 is currently installed
# train: Scanning '/content/yolov5/../data/labels/train.cache' images and labels... 51 found, 0 missing, 0 empty, 0 corrupt: 100% 51/51 [00:00<?, ?it/s]
# train: Caching images (0.0GB ram): 100% 51/51 [00:02<00:00, 18.91it/s]
# val: Scanning '/content/yolov5/../data/labels/val.cache' images and labels... 7 found, 0 missing, 0 empty, 0 corrupt: 100% 7/7 [00:00<?, ?it/s]
# val: Caching images (0.0GB ram): 100% 7/7 [00:00<00:00,  9.76it/s]
# Plotting labels to runs/train/exp3/labels.jpg...
#
# AutoAnchor: 2.82 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp3
# Starting training for 70 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       0/69     1.11G   0.08923   0.03203   0.03533         4       640: 100% 11/11 [00:07<00:00,  1.53it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.65it/s]
#                  all          7          7     0.0141        0.5     0.0189    0.00504
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       1/69     1.11G   0.07973   0.03127   0.03415         4       640: 100% 11/11 [00:04<00:00,  2.40it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.29it/s]
#                  all          7          7      0.109      0.125     0.0972     0.0192
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       2/69     1.11G      0.06   0.03001    0.0287         2       640: 100% 11/11 [00:04<00:00,  2.44it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.83it/s]
#                  all          7          7      0.735      0.125      0.237     0.0547
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       3/69     1.11G   0.06389   0.03257   0.03352         4       640: 100% 11/11 [00:04<00:00,  2.42it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.80it/s]
#                  all          7          7      0.228       0.75       0.44      0.204
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       4/69     1.11G   0.04763   0.02975   0.02867         4       640: 100% 11/11 [00:04<00:00,  2.43it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.54it/s]
#                  all          7          7      0.526      0.616      0.439      0.197
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       5/69     1.11G   0.06804   0.02843   0.03365         4       640: 100% 11/11 [00:04<00:00,  2.43it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.73it/s]
#                  all          7          7      0.496      0.874      0.523      0.265
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       6/69     1.11G   0.05414   0.02576   0.03014         2       640: 100% 11/11 [00:04<00:00,  2.45it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.73it/s]
#                  all          7          7      0.459      0.875       0.54      0.263
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       7/69     1.11G   0.05026   0.02978    0.0286         4       640: 100% 11/11 [00:04<00:00,  2.44it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.66it/s]
#                  all          7          7      0.673        0.5      0.559      0.246
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       8/69     1.11G   0.05397   0.02351    0.0253         2       640: 100% 11/11 [00:04<00:00,  2.44it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.13it/s]
#                  all          7          7      0.138      0.625      0.156      0.027
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       9/69     1.11G    0.0613   0.02403    0.0305         4       640: 100% 11/11 [00:04<00:00,  2.45it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.89it/s]
#                  all          7          7      0.271       0.75      0.473      0.159
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      10/69     1.11G   0.05278   0.02336   0.02632         2       640: 100% 11/11 [00:04<00:00,  2.45it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.54it/s]
#                  all          7          7      0.152      0.676      0.242      0.133
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      11/69     1.11G   0.06546   0.02161   0.02734         2       640: 100% 11/11 [00:04<00:00,  2.43it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.22it/s]
#                  all          7          7      0.223        0.5      0.277      0.139
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      12/69     1.11G   0.05042   0.01625   0.02449         1       640: 100% 11/11 [00:04<00:00,  2.47it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.44it/s]
#                  all          7          7      0.223        0.5      0.277      0.139
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      13/69     1.11G   0.05429   0.02315   0.02242         2       640: 100% 11/11 [00:04<00:00,  2.44it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.83it/s]
#                  all          7          7      0.218      0.859       0.32      0.129
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
00:00,  2.45it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.63it/s]
#                  all          7          7      0.605      0.985      0.829      0.535
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      55/69     1.11G   0.02374   0.01504   0.01264         2       640: 100% 11/11 [00:04<00:00,  2.45it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.88it/s]
#                  all          7          7      0.651          1      0.829      0.541
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      56/69     1.11G   0.02847   0.01898   0.01847         4       640: 100% 11/11 [00:04<00:00,  2.44it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.00it/s]
#                  all          7          7      0.663      0.998      0.829      0.609
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      57/69     1.11G   0.02471   0.01391   0.01797         1       640: 100% 11/11 [00:04<00:00,  2.46it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.51it/s]
#                  all          7          7      0.663      0.998      0.829      0.609
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      58/69     1.11G    0.0248   0.01749    0.0198         4       640: 100% 11/11 [00:04<00:00,  2.45it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.52it/s]
#                  all          7          7      0.652          1      0.829      0.618
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      59/69     1.11G   0.03011   0.01538   0.01315         2       640: 100% 11/11 [00:04<00:00,  2.43it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.24it/s]
#                  all          7          7      0.644          1      0.829      0.636
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      60/69     1.11G   0.02386   0.01696   0.01847         4       640: 100% 11/11 [00:04<00:00,  2.44it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.27it/s]
#                  all          7          7      0.651          1      0.829      0.599
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      61/69     1.11G   0.02117   0.01434   0.01455         3       640: 100% 11/11 [00:04<00:00,  2.44it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.50it/s]
#                  all          7          7       0.65          1      0.829      0.578
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      62/69     1.11G   0.02114   0.01311    0.0133         2       640: 100% 11/11 [00:04<00:00,  2.47it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.59it/s]
#                  all          7          7      0.652          1      0.829       0.61
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      63/69     1.11G   0.02738   0.01326   0.01659         1       640: 100% 11/11 [00:04<00:00,  2.43it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.82it/s]
#                  all          7          7      0.664          1      0.829      0.585
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      64/69     1.11G   0.02905   0.01607   0.01523         4       640: 100% 11/11 [00:04<00:00,  2.44it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.70it/s]
#                  all          7          7      0.664          1      0.829      0.585
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      65/69     1.11G   0.02517    0.0153   0.01611         4       640: 100% 11/11 [00:04<00:00,  2.44it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.04it/s]
#                  all          7          7       0.67          1      0.829       0.56
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      66/69     1.11G   0.02058   0.01493   0.01333         2       640: 100% 11/11 [00:04<00:00,  2.44it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.05it/s]
#                  all          7          7      0.668          1      0.829      0.585
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      67/69     1.11G   0.02118   0.01418   0.01619         3       640: 100% 11/11 [00:04<00:00,  2.43it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.17it/s]
#                  all          7          7      0.666          1      0.829      0.585
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      68/69     1.11G   0.02713   0.01441   0.01281         4       640: 100% 11/11 [00:04<00:00,  2.43it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.45it/s]
#                  all          7          7      0.661          1      0.829      0.597
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      69/69     1.11G   0.01921   0.01216   0.01815         4       640: 100% 11/11 [00:04<00:00,  2.44it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.32it/s]
#                  all          7          7      0.672      0.998      0.829      0.579
#
# 70 epochs completed in 0.101 hours.
# Optimizer stripped from runs/train/exp3/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/exp3/weights/best.pt, 14.4MB
#
# Validating runs/train/exp3/weights/best.pt...
# Fusing layers...
# Model summary: 213 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.00it/s]
#                  all          7          7      0.678      0.978      0.953      0.646
#                right          7          1      0.945          1      0.995      0.895
#             sleeping          7          2          1       0.91      0.995      0.497
#          distraction          7          2      0.357          1      0.828      0.547
#            too close          7          2      0.409          1      0.995      0.646
# Results saved to runs/train/exp3

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Weights & Biases Logging 🌟 NEW
#
# [Weights & Biases](https://wandb.ai/site?utm_campaign=repo_yolo_notebook) (W&B) is now integrated with YOLOv5 for real-time visualization and cloud logging of training runs. This allows for better run comparison and introspection, as well improved visibility and collaboration for teams. To enable W&B `pip install wandb`, and then train normally (you will be guided through setup on first use).
#
# During training you will see live updates at [https://wandb.ai/home](https://wandb.ai/home?utm_campaign=repo_yolo_notebook), and you can create and share detailed [Reports](https://wandb.ai/glenn-jocher/yolov5_tutorial/reports/YOLOv5-COCO128-Tutorial-Results--VmlldzozMDI5OTY) of your results. For more information see the [YOLOv5 Weights & Biases Tutorial](https://github.com/ultralytics/yolov5/issues/1289).
#
# <p align="left"><img width="900" alt="Weights & Biases dashboard" src="https://user-images.githubusercontent.com/26833433/135390767-c28b050f-8455-4004-adb0-3b730386e2b2.png"></p>

# %% [markdown]
# ## Local Logging
#
# All results are logged by default to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc. View train and val jpgs to see mosaics, labels, predictions and augmentation effects. Note an Ultralytics **Mosaic Dataloader** is used for training (shown below), which combines 4 images into 1 mosaic during training.
#
# > <img src="https://user-images.githubusercontent.com/26833433/131255960-b536647f-7c61-4f60-bbc5-cb2544d71b2a.jpg" width="700">
# `train_batch0.jpg` shows train batch 0 mosaics and labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/131256748-603cafc7-55d1-4e58-ab26-83657761aed9.jpg" width="700">
# `test_batch0_labels.jpg` shows val batch 0 labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/131256752-3f25d7a5-7b0f-4bb3-ab78-46343c3800fe.jpg" width="700">
# `test_batch0_pred.jpg` shows val batch 0 _predictions_
#
# Training results are automatically logged to [Tensorboard](https://www.tensorflow.org/tensorboard) and [CSV](https://github.com/ultralytics/yolov5/pull/4148) as `results.csv`, which is plotted as `results.png` (below) after training completes. You can also plot any `results.csv` file manually:
#
# ```python
# from utils.plots import plot_results
# plot_results('path/to/results.csv')  # plot 'results.csv' as 'results.png'
# ```
#
# <img align="left" width="800" alt="COCO128 Training Results" src="https://user-images.githubusercontent.com/26833433/126906780-8c5e2990-6116-4de6-b78a-367244a33ccf.png">

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Google Colab and Kaggle** notebooks with free GPU: <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/GCP-Quickstart)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/AWS-Quickstart)
# - **Docker Image**. See [Docker Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/Docker-Quickstart) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![CI CPU testing](https://github.com/ultralytics/yolov5/workflows/CI%20CPU%20testing/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([val.py](https://github.com/ultralytics/yolov5/blob/master/val.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on MacOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Optional extras below. Unit tests validate repo functionality and should be run on any PRs submitted.

# %%
# Reproduce
for x in 'yolov5n', 'yolov5s', 'yolov5m', 'yolov5l', 'yolov5x':
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --task speed  # speed
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.001 --iou 0.65  # mAP

# %%
# PyTorch Hub
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Images
dir = 'https://ultralytics.com/images/'
imgs = [dir + f for f in ('zidane.jpg', 'bus.jpg')]  # batch of images

# Inference
results = model(imgs)
results.print()  # or .show(), .save()

# %%
# CI Checks
# %%shell
export PYTHONPATH="$PWD"  # to run *.py. files in subdirectories
rm -rf runs  # remove runs/
for m in yolov5n; do  # models
  python train.py --img 64 --batch 32 --weights $m.pt --epochs 1 --device 0  # train pretrained
  python train.py --img 64 --batch 32 --weights '' --cfg $m.yaml --epochs 1 --device 0  # train scratch
  for d in 0 cpu; do  # devices
    python val.py --weights $m.pt --device $d # val official
    python val.py --weights runs/train/exp/weights/best.pt --device $d # val custom
    python detect.py --weights $m.pt --device $d  # detect official
    python detect.py --weights runs/train/exp/weights/best.pt --device $d  # detect custom
  done
  python hubconf.py  # hub
  python models/yolo.py --cfg $m.yaml  # build PyTorch model
  python models/tf.py --weights $m.pt  # build TensorFlow model
  python export.py --img 64 --batch 1 --weights $m.pt --include torchscript onnx  # export
done

# %%
# Profile
from utils.torch_utils import profile

m1 = lambda x: x * torch.sigmoid(x)
m2 = torch.nn.SiLU()
results = profile(input=torch.randn(16, 3, 640, 640), ops=[m1, m2], n=100)

# %%
# Evolve
# !python train.py --img 640 --batch 64 --epochs 100 --data coco128.yaml --weights yolov5s.pt --cache --noautoanchor --evolve
# !d=runs/train/evolve && cp evolve.* $d && zip -r evolve.zip $d && gsutil mv evolve.zip gs://bucket  # upload results (optional)

# %%
# VOC
for b, m in zip([64, 64, 32, 16], ['yolov5s', 'yolov5m', 'yolov5l', 'yolov5x']):  # zip(batch_size, model)
  # !python train.py --batch {b} --weights {m}.pt --data VOC.yaml --epochs 50 --cache --img 512 --nosave --hyp hyp.VOC.yaml --project VOC --name {m}

# %%
# TensorRT 
# https://docs.nvidia.com/deeplearning/tensorrt/install-guide/index.html#installing-pip
# !pip install -U nvidia-tensorrt --index-url https://pypi.ngc.nvidia.com  # install
# !python export.py --weights yolov5s.pt --include engine --imgsz 640 640 --device 0  # export
# !python detect.py --weights yolov5s.engine --imgsz 640 640 --device 0  # inference
